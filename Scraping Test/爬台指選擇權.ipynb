# %%
import requests
res = requests.get('http://www.taifex.com.tw/cht/3/optDailyMarketReport')
#res.text

# %%
import pandas
dfs = pandas.read_html('http://www.taifex.com.tw/cht/3/optDailyMarketReport')

# %%
dfs[2]
# Out:
#                                                   0     \
# 0                                                  NaN
# 1    日期：2018/12/22  臺指選擇權 (  TXO  ) 行情表 2018/12/22 ...
# 2    臺指選擇權 (  TXO  ) 行情表 2018/12/22 08:45~13:45 一般交...
# 3                                                   契約
# 4                                                  TXO
# 5                                                  TXO
# 6                                                  TXO
# 7                                                  TXO
# 8                                                  TXO
# 9                                                  TXO
# 10                                                 TXO
# 11                                                 TXO
# 12                                                 TXO
# 13                                                 TXO
# 14                                                 TXO
# 15                                                 TXO
# ...

# %%
import pandas
dfs = pandas.read_html('http://www.taifex.com.tw/cht/3/optDailyMarketReport')
r=dfs[4]
#r.columns =r.loc[0]
#r.drop(r.columns[8:],axis=0)
r
#COP=r.iloc[0:396,[1,2,3,7]]
#COP
# Out:
#                          0         1      2     3     4     5     6      7   \
# 0                        契約  到期月份(週別)    履約價   買賣權   開盤價   最高價   最低價  最後成交價
# 1                       TXO  201812W4   8900  Call     -     -     -      -
# 2                       TXO  201812W4   8900   Put   2.6   2.9     2    2.7
# 3                       TXO  201812W4   9000  Call   630   630   625    625
# 4                       TXO  201812W4   9000   Put   3.4   4.2   2.9    4.2
# 5                       TXO  201812W4   9100  Call     -     -     -      -
# 6                       TXO  201812W4   9100   Put     5   5.9   3.7    5.8
# 7                       TXO  201812W4   9200  Call   430   431   424    424
# 18                      TXO  201812W4   9550   Put    57    61  44.5     57
# 19                      TXO  201812W4   9600  Call    86    98    78     82
# 20                      TXO  201812W4   9600   Put    76    80    60     74
# ...

# %%
dfs[4]
# Out:
#                          0         1      2     3     4     5     6      7   \
# 0                        契約  到期月份(週別)    履約價   買賣權   開盤價   最高價   最低價  最後成交價
# 1                       TXO  201812W4   8900  Call     -     -     -      -
# 2                       TXO  201812W4   8900   Put   2.6   2.9     2    2.7
# 3                       TXO  201812W4   9000  Call   630   630   625    625
# 4                       TXO  201812W4   9000   Put   3.4   4.2   2.9    4.2
# 5                       TXO  201812W4   9100  Call     -     -     -      -
# 6                       TXO  201812W4   9100   Put     5   5.9   3.7    5.8
# 7                       TXO  201812W4   9200  Call   430   431   424    424
# 8                       TXO  201812W4   9200   Put     8     9   5.7      9
# 9                       TXO  201812W4   9300  Call   326   333   326    333
# 10                      TXO  201812W4   9300   Put  13.5    15   9.8     15
# ...

# %%
from selenium import webdriver
driver = webdriver.Chrome('./chromedriver')

# %%
driver.get('http://www.taifex.com.tw/cht/3/optDailyMarketReport')

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(driver.page_source,'lxml')

# %%
import requests
from bs4 import BeautifulSoup 
payload ={
'queryType': '2',
'marketCode': '0',
'dateaddcnt': '',
'commodity_id': 'TXO',
'commodity_id2': '',
'queryDate': '2018/12/22',
'MarketCode': '0',
'commodity_idt': 'TXO',
'commodity_id2t':'' ,
'commodity_id2t2':'',
}
rs = requests.session()
res=rs.post('http://www.taifex.com.tw/cht/3/optDailyMarketReport',data = payload)
res2=rs.get('http://www.taifex.com.tw/cht/3/optDailyMarketReport')
soup = BeautifulSoup(res2.text,'lxml')
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
# <html lang="zh-TW" xmlns="http://www.w3.org/1999/xhtml">
# <head><meta content="IE=edge" http-equiv="X-UA-Compatible"/></head><!DOCTYPE html>
#
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/cht/resources/front/cht/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="http://www.taifex.com.tw/cht/images/fb_logo.jpg" property="og:image"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>交易資訊/交易資訊/選擇權/選擇權每日交易行情查詢</title>
# <link href="/cht/resources/front/cht/css/global.css" rel="stylesheet" type="text/css"/>
# <link href="/cht/resources/front/cht/css/content.css" rel="stylesheet" type="text/css"/>
# <link href="/cht/resources/front/cht/css/index.css" rel="stylesheet" type="text/css"/>
# ...

# %%
import requests
import re
import json
from bs4 import BeautifulSoup 

payload ={
'queryType': '2',
'marketCode': '0',
'dateaddcnt': '',
'commodity_id': 'TXO',
'commodity_id2': '',
'queryDate': '2018/12/28',
'MarketCode': '0',
'commodity_idt': 'TXO',
'commodity_id2t':'' ,
'commodity_id2t2':'',
}

rs = requests.session()

res=rs.post('http://www.taifex.com.tw/cht/3/optDailyMarketReport',data = payload)
soup = BeautifulSoup(res.text,'lxml')
m = re.findall('(<td class="12bk"><div align="center">.*</td>)',res.text)
m

#data=res.json()
#print (data)
#res2=rs.get('http://www.taifex.com.tw/cht/3/optDailyMarketReport')
#for td in soup.select('.content td '):
#       print (td.select('.12bk '))
# Out:
# ['<td class="12bk"><div align="center">201901W1</div></td>',
#  '<td class="12bk"><div align="center">201901W1</div></td>',
#  '<td class="12bk"><div align="center">201901W1</div></td>',
#  '<td class="12bk"><div align="center">201901W1</div></td>',
#  '<td class="12bk"><div align="center">201901W1</div></td>',
#  '<td class="12bk"><div align="center">201901W1</div></td>',
#  '<td class="12bk"><div align="center">201901W1</div></td>',
#  '<td class="12bk"><div align="center">201901W1</div></td>',
#  '<td class="12bk"><div align="center">201901W1</div></td>',
#  '<td class="12bk"><div align="center">201901W1</div></td>',
#  '<td class="12bk"><div align="center">201901W1</div></td>',
#  '<td class="12bk"><div align="center">201901W1</div></td>',
#  '<td class="12bk"><div align="center">201901W1</div></td>',
#  '<td class="12bk"><div align="center">201901W1</div></td>',
#  '<td class="12bk"><div align="center">201901W1</div></td>',
# ...

# %%
import requests
from bs4 import BeautifulSoup 
import pandas

url='http://www.taifex.com.tw/cht/3/optDailyMarketReport'

payload ={
'queryType': '2',
'marketCode': '0',
'dateaddcnt': '',
'commodity_id': 'TXO',
'commodity_id2': '',
'queryDate': '2018/12/21',
'MarketCode': '0',
'commodity_idt': 'TXO',
'commodity_id2t':'' ,
'commodity_id2t2':'',
}
rs = requests.session()
res=rs.post(url)
res2=rs.get(url)

dfs = pandas.read_html(url,data = payload)
dfs
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-e5090ff9a498> in <module>()
#      21 res2=rs.get(url)
#      22
# ---> 23 dfs = pandas.read_html(url,data = payload)
#      24 dfs
#
# TypeError: read_html() got an unexpected keyword argument 'data'

# %%
import pandas as pd
url = 'http://www.stockq.org/market/asia.php'
table = pd.read_html(url)[4]
table = table.drop(table.columns[[0,1,2,3,4]],axis=0)
table = table.drop(table.columns[9:296],axis=1)
table
# Out:
#                                                     0         1        2  \
# 5                                                 紐西蘭   8686.19   -86.00
# 6                                                澳洲股市   5533.30   -39.60
# 7                                               日經225  20166.19  -226.39
# 8                                                東證一部   1488.19   -28.97
# 9                                                東證二部   6165.75  -197.05
# 10                                             JASDAQ    135.85    -3.45
# 11                                               韓國股市   2061.49     1.37
# 12                                               台灣加權   9646.22   -30.45
# 13                                               台灣店頭    123.66    -0.36
# 14                                               上海綜合   2516.25   -20.02
# 15                                               上海A股   2634.80   -20.93
# 16                                               上海B股    273.15    -3.19
# ...

# %%
import pandas as pd
url1='http://www.taifex.com.tw/cht/3/optDailyMarketReport'
r = pd.read_html(url1)[4]
r = r.drop(r.columns[8:19],axis=1)
r
# Out:
#                           0         1      2     3     4     5     6      7
# 0                        契約  到期月份(週別)    履約價   買賣權   開盤價   最高價   最低價  最後成交價
# 1                       TXO  201812W4   8900  Call     -     -     -      -
# 2                       TXO  201812W4   8900   Put   2.6   2.9     2    2.7
# 3                       TXO  201812W4   9000  Call   630   630   625    625
# 4                       TXO  201812W4   9000   Put   3.4   4.2   2.9    4.2
# 5                       TXO  201812W4   9100  Call     -     -     -      -
# 6                       TXO  201812W4   9100   Put     5   5.9   3.7    5.8
# 7                       TXO  201812W4   9200  Call   430   431   424    424
# 8                       TXO  201812W4   9200   Put     8     9   5.7      9
# 9                       TXO  201812W4   9300  Call   326   333   326    333
# 10                      TXO  201812W4   9300   Put  13.5    15   9.8     15
# ...

# %%
# 當日買權履約價與成交價
import pandas as pd
url2='http://www.taifex.com.tw/cht/3/optDailyMarketSummary'
c= pd.read_html(url2)[4]
c = c.drop(c.columns[5:9],axis=1)
c=c.drop(c.columns[2:4],axis=1)
c.columns =("買權到期月份(週別)","履約價","成交價")
c.drop([0],inplace=True)

c

# %%
#當日賣權履約價與成交價
p=pd.read_html(url2)[7]

p = p.drop(p.columns[5:9],axis=1)
p = p.drop(p.columns[2:4],axis=1)
p.columns  =("賣權到期月份(週別)","履約價","成交價")
p.drop([0],inplace=True)
p
# Out:
#              賣權到期月份(週別)    履約價   成交價
# 1              201812W4   9400    25
# 2              201812W4   9450    32
# 3              201812W4   9500  43.5
# 4              201812W4   9550    57
# 5              201812W4   9600    74
# 6              201812W4   9650    97
# 7              201812W4   9700   126
# 8              201812W4   9750   160
# 9              201812W4   9800   202
# 10             201812W4   9850   233
# 11               201901   8700  29.5
# 12               201901   8800  35.5
# 13               201901   8900    44
# 14               201901   9000    53
# 15               201901   9100    69
# 16               201901   9200    83
# 17               201901   9300   104
# 18               201901   9400   130
# 19               201901   9500   162
# 20               201901   9600   202
# 21               201901   9700   254
# 22               201901   9800   308
# 23               201901   9900   378
# 24               201901  10000   459
# ...

# %%
#固定日期爬取期交所選擇權成交價
import requests
import re
import json
from bs4 import BeautifulSoup 

payload ={
'queryType': '2',
'marketCode': '0',
'dateaddcnt': '',
'commodity_id': 'TXO',
'commodity_id2': '',
'queryDate': '2018/12/12',
'MarketCode': '0',
'commodity_idt': 'TXO',
'commodity_id2t':'' ,
'commodity_id2t2':'',
}

rs = requests.session()

res=rs.post('http://www.taifex.com.tw/cht/3/optDailyMarketReport',data = payload)
soup = BeautifulSoup(res.text,'lxml')
for tr in  soup.select('.section tr')[11:469]:
    td = tr.select('td')
    print (td[0].text,td[1].text,td[2].text,td[3].text,td[7].text)
# Out:
# TXO
#  201812W2 8900 Call -
#
# TXO
#  201812W2 8900 Put 0.1
#
# TXO
#  201812W2 9000 Call -
#
# TXO
#  201812W2 9000 Put 0.1
#
# TXO
#  201812W2 9100 Call -
#
# TXO
#  201812W2 9100 Put 0.1
#
# TXO
#  201812W2 9200 Call 585
#
# TXO
#  201812W2 9200 Put 0.1
#
# TXO
#  201812W2 9300 Call -
#
# TXO
#  201812W2 9300 Put 0.1
#
# TXO
#  201812W2 9400 Call -
#
# TXO
#  201812W2 9400 Put 0.1
#
# TXO
#  201812W2 9450 Call 383
#
# TXO
#  201812W2 9450 Put 0.1
#
# TXO
#  201812W2 9500 Call 329
#
# TXO
#  201812W2 9500 Put 0.1
#
# TXO
#  201812W2 9550 Call 279
#
# TXO
#  201812W2 9550 Put 0.1
#
# TXO
#  201812W2 9600 Call 229
#
# TXO
#  201812W2 9600 Put 0.1
#
# TXO
#  201812W2 9650 Call 180
#
# TXO
#  201812W2 9650 Put 0.1
#
# TXO
#  201812W2 9700 Call 129
#
# TXO
#  201812W2 9700 Put 0.1
#
# TXO
#  201812W2 9750 Call 79
#
# TXO
#  201812W2 9750 Put 0.1
#
# TXO
#  201812W2 9800 Call 29.5
#
# TXO
#  201812W2 9800 Put 0.1
#
# TXO
#  201812W2 9850 Call 0.1
#
# TXO
#  201812W2 9850 Put 21
#
# TXO
# ...

# %%
## Final Code 輸入日期來爬取期交所選擇權成交價
import requests
from bs4 import BeautifulSoup 



def findoptionvalue(date):
    payload ={
    'queryType': '2',
    'marketCode': '0',
    'dateaddcnt': '',
    'commodity_id': 'TXO',
    'commodity_id2': '',
    'queryDate': format(date),
    'MarketCode': '0',
    'commodity_idt': 'TXO',
    'commodity_id2t':'' ,
    'commodity_id2t2':'',
    }
    rs = requests.session()
    res=rs.post('http://www.taifex.com.tw/cht/3/optDailyMarketReport',data = payload)
    soup = BeautifulSoup(res.text,'lxml')
    for tr in  soup.select('.section tr')[11:455]:
        td = tr.select('td')
        print (td[0].text,td[1].text,td[2].text,td[3].text,td[7].text)
        
findoptionvalue('2018/12/12')
# Out:
# TXO
#  201812W2 8900 Call -
#
# TXO
#  201812W2 8900 Put 0.1
#
# TXO
#  201812W2 9000 Call -
#
# TXO
#  201812W2 9000 Put 0.1
#
# TXO
#  201812W2 9100 Call -
#
# TXO
#  201812W2 9100 Put 0.1
#
# TXO
#  201812W2 9200 Call 585
#
# TXO
#  201812W2 9200 Put 0.1
#
# TXO
#  201812W2 9300 Call -
#
# TXO
#  201812W2 9300 Put 0.1
#
# TXO
#  201812W2 9400 Call -
#
# TXO
#  201812W2 9400 Put 0.1
#
# TXO
#  201812W2 9450 Call 383
#
# TXO
#  201812W2 9450 Put 0.1
#
# TXO
#  201812W2 9500 Call 329
#
# TXO
#  201812W2 9500 Put 0.1
#
# TXO
#  201812W2 9550 Call 279
#
# TXO
#  201812W2 9550 Put 0.1
#
# TXO
#  201812W2 9600 Call 229
#
# TXO
#  201812W2 9600 Put 0.1
#
# TXO
#  201812W2 9650 Call 180
#
# TXO
#  201812W2 9650 Put 0.1
#
# TXO
#  201812W2 9700 Call 129
#
# TXO
#  201812W2 9700 Put 0.1
#
# TXO
#  201812W2 9750 Call 79
#
# TXO
#  201812W2 9750 Put 0.1
#
# TXO
#  201812W2 9800 Call 29.5
#
# TXO
#  201812W2 9800 Put 0.1
#
# TXO
#  201812W2 9850 Call 0.1
#
# TXO
#  201812W2 9850 Put 21
#
# TXO
# ...
