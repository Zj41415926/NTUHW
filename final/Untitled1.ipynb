# %%
import pickle
import pandas as pd
import numpy as np

# %%
List = pd.read_fwf('chosen_list.txt')
Nodata = pd.read_fwf('nodata.txt')

# %%
result=[]
fd = open( "chosen_list.txt", "r" )
 
for line in fd.readlines():
    result.append(list(map(int,line.split(','))))
print(result)
# Out:
# <_io.TextIOWrapper name='chosen_list.txt' mode='r' encoding='cp950'>

# %%
List
# Out:
#       INVE
# 0     ELON
# 1     PEGA
# 2     PRCP
# 3     CASS
# 4     COHU
# 5     BBOX
# 6      BDR
# 7     CRTN
# 8     HMNY
# 9    BELFB
# 10    CDNS
# 11    KLAC
# 12      CY
# 13    XLNX
# 14    ZOOM
# 15    TACT
# 16    WGNR
# 17    NVDA
# 18    CMTL
# 19     AXE
# 20    TTWO
# 21     KEM
# 22    EVOL
# 23    TKLC
# 24    ESIO
# 25      IT
# 26    MSCC
# 27    INTC
# 28    ANEN
# 29   AMSWA
# ..     ...
# 169   AEIS
# 170   ENVE
# 171    TCX
# 172   EGHT
# 173   COVR
# 174    AMD
# 175   ACCL
# 176   MCRL
# 177    WDC
# 178   OSIS
# 179   CREE
# 180   SNDK
# 181   PFSW
# 182   EDGW
# 183   ATEA
# 184   KLIC
# 185    NCR
# 186   CNXN
# 187    IDT
# 188    AVX
# 189   ISIL
# 190    LGL
# 191   FEIM
# 192   ATNI
# 193   QADA
# 194   TRMB
# 195   DTLK
# 196   PCMI
# 197   CTSH
# 198   VIAV
#
# [199 rows x 1 columns]

# %%
Nodata
# Out:
#     ELON
# 0   CRTN
# 1   TKLC
# 2   ESIO
# 3   MSCC
# 4   IXYS
# 5   LIOX
# 6   PSEM
# 7   DWCH
# 8   ONVI
# 9   ADCT
# 10  CHYR
# 11   CVG
# 12  MATR
# 13  NEWP
# 14   EMC
# 15  UTEK
# 16  XRIT
# 17   DST
# 18   CKP
# 19  HTCH
# 20  LLTC
# 21  RSTI
# 22   FRP
# 23  RSYS
# 24  TIII
# 25  NMRX
# 26  MTSN
# 27  ACTA
# 28   MWW
# 29  ANAD
# 30  ELMG
# 31  EPIQ
# 32  HILL
# 33  ADVS
# 34   LXK
# 35  QLGC
# 36  PLNR
# 37  CACI
# 38  XCRA
# 39   PGI
# 40  MEAS
# 41  BTUI
# 42  ENVE
# 43  COVR
# 44  MCRL
# 45  SNDK
# 46  EDGW
# 47  ISIL
# 48  DTLK

# %%
import sys
result1=[]
result2=[]
with open('chosen_list.txt','r') as f:
    for line in f:
        result1.append(list(line.strip('\n').split(',')))

with open('Nodata.txt','r') as f:
    for line in f:
        result2.append(list(line.strip('\n').split(',')))

# %%
a=(['INVE'],
 ['ELON'],
 ['PEGA'],
 ['PRCP'],
 ['CASS'],
 ['COHU'],
 ['BBOX'],
 ['BDR'],
 ['CRTN'],
 ['HMNY'],
 ['BELFB'],
 ['CDNS'],
 ['KLAC'],
 ['CY'],
 ['XLNX'],
 ['ZOOM'],
 ['TACT'],
 ['WGNR'],
 ['NVDA'],
 ['CMTL'],
 ['AXE'],
 ['TTWO'],
 ['KEM'],
 ['EVOL'],
 ['TKLC'],
 ['ESIO'],
 ['IT'],
 ['MSCC'],
 ['INTC'],
 ['ANEN'],
 ['AMSWA'],
 ['SYMC'],
 ['AMKR'],
 ['IXYS'],
 ['LIOX'],
 ['PSEM'],
 ['SPDC'],
 ['CSCO'],
 ['DWCH'],
 ['TLAB'],
 ['SHEN'],
 ['ONVI'],
 ['XRX'],
 ['BHE'],
 ['INTT'],
 ['INAP'],
 ['ADCT'],
 ['FTR'],
 ['CRAY'],
 ['SMIT'],
 ['CHYR'],
 ['CTS'],
 ['GVP'],
 ['OLED'],
 ['CVG'],
 ['CYBE'],
 ['MATR'],
 ['MTSC'],
 ['MCHP'],
 ['ESCC'],
 ['CTL'],
 ['APH'],
 ['LFUS'],
 ['RMTR'],
 ['NEWP'],
 ['VSAT'],
 ['LSCC'],
 ['EMC'],
 ['ON'],
 ['TDS'],
 ['PAR'],
 ['AAPL'],
 ['PAYX'],
 ['AXTI'],
 ['UTEK'],
 ['EGOV'],
 ['MMS'],
 ['CELL'],
 ['XRIT'],
 ['DST'],
 ['INTU'],
 ['MSI'],
 ['TRT'],
 ['FDC'],
 ['CKP'],
 ['MSFT'],
 ['QUIK'],
 ['INOD'],
 ['DGII'],
 ['HTCH'],
 ['NIHD'],
 ['LLTC'],
 ['CSGS'],
 ['DAIO'],
 ['RSTI'],
 ['DDD'],
 ['ASYS'],
 ['WTT'],
 ['EA'],
 ['FRP'],
 ['ITI'],
 ['RSYS'],
 ['TIII'],
 ['NMRX'],
 ['STCN'],
 ['DIOD'],
 ['MTSN'],
 ['NSYS'],
 ['PLT'],
 ['CYMI'],
 ['ACTA'],
 ['MU'],
 ['ZIXI'],
 ['KVHI'],
 ['NWK'],
 ['DRCO'],
 ['FICO'],
 ['MSTR'],
 ['IBM'],
 ['BRKS'],
 ['CSPI'],
 ['MWW'],
 ['FSII'],
 ['TYL'],
 ['TXN'],
 ['ADBE'],
 ['HLIT'],
 ['ANAD'],
 ['ELMG'],
 ['FALC'],
 ['ALOT'],
 ['CBB'],
 ['EPIQ'],
 ['PKE'],
 ['SUPX'],
 ['ADI'],
 ['HILL'],
 ['FARO'],
 ['KODK'],
 ['FFIV'],
 ['ADVS'],
 ['EEFT'],
 ['FLEX'],
 ['LXK'],
 ['QLGC'],
 ['PLNR'],
 ['VECO'],
 ['MKSI'],
 ['AWRE'],
 ['CACI'],
 ['FLIR'],
 ['XCRA'],
 ['IAC'],
 ['TSS'],
 ['CIEN'],
 ['PGI'],
 ['TESS'],
 ['MEAS'],
 ['MXWL'],
 ['PRST'],
 ['EBIX'],
 ['BTUI'],
 ['IEC'],
 ['OSPN'],
 ['VSH'],
 ['ASUR'],
 ['ZBRA'],
 ['PCTI'],
 ['TER'],
 ['ANSS'],
 ['AEIS'],
 ['ENVE'],
 ['TCX'],
 ['EGHT'],
 ['COVR'],
 ['AMD'],
 ['ACCL'],
 ['MCRL'],
 ['WDC'],
 ['OSIS'],
 ['CREE'],
 ['SNDK'],
 ['PFSW'],
 ['EDGW'],
 ['ATEA'],
 ['KLIC'],
 ['NCR'],
 ['CNXN'],
 ['IDT'],
 ['AVX'],
 ['ISIL'],
 ['LGL'],
 ['FEIM'],
 ['ATNI'],
 ['QADA'],
 ['TRMB'],
 ['DTLK'],
 ['PCMI'],
 ['CTSH'],
 ['VIAV'])

# %%
b=(['ELON'],
 ['CRTN'],
 ['TKLC'],
 ['ESIO'],
 ['MSCC'],
 ['IXYS'],
 ['LIOX'],
 ['PSEM'],
 ['DWCH'],
 ['ONVI'],
 ['ADCT'],
 ['CHYR'],
 ['CVG'],
 ['MATR'],
 ['NEWP'],
 ['EMC'],
 ['UTEK'],
 ['XRIT'],
 ['DST'],
 ['CKP'],
 ['HTCH'],
 ['LLTC'],
 ['RSTI'],
 ['FRP'],
 ['RSYS'],
 ['TIII'],
 ['NMRX'],
 ['MTSN'],
 ['ACTA'],
 ['MWW'],
 ['ANAD'],
 ['ELMG'],
 ['EPIQ'],
 ['HILL'],
 ['ADVS'],
 ['LXK'],
 ['QLGC'],
 ['PLNR'],
 ['CACI'],
 ['XCRA'],
 ['PGI'],
 ['MEAS'],
 ['BTUI'],
 ['ENVE'],
 ['COVR'],
 ['MCRL'],
 ['SNDK'],
 ['EDGW'],
 ['ISIL'],
 ['DTLK'])

# %%
 
s1 = set(result1)
s2 = set(result2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-cf7fc39043ea> in <module>
#       1
#       2
# ----> 3 s1 = set(result1)
#       4 s2 = set(result2)
#       5
#
# TypeError: unhashable type: 'list'

# %%
def diff(list1, list2):
    return list(set(list1).symmetric_difference(set(list2)))

# %%
diff(a,b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-686c3edc52e5> in <module>
# ----> 1 diff(a,b)
#
# <ipython-input-24-d53b43b3484e> in diff(list1, list2)
#       1 def diff(list1, list2):
# ----> 2     return list(set(list1).symmetric_difference(set(list2)))
#
# TypeError: unhashable type: 'list'
